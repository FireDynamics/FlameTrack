# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import user_config as ucfg
import os

# %%
colors = {'R1':'b',
          'R2':"r",
            'R3':'g',
            'R4':'c',
          }

# %%
fig,ax = plt.subplots(figsize=(10,10))
for file in os.listdir(os.path.join(ucfg.get_path('csv_folder'))):
    if 'R1' not in file or file.startswith('.'):
        continue
  
    df =pd.read_csv(os.path.join(ucfg.get_path('csv_folder'),file),header=None)
    if 'LFS' in file:
        df = df[150:]
    ax.plot(df.values)
    
ax.axhline(774,linestyle = '--')
ax.grid()
